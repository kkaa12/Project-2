# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as st
import statsmodels.api as sm
from scipy.stats.contingency import association
from scipy.stats import chi2_contingency
from scipy import stats

# %matplotlib inline

# %%
df_demo = pd.read_csv('df_final_demo.txt')
df_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30           6.0            9.0
# 1       110860.30           6.0            9.0
# 2        52467.79           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# ...           ...           ...            ...
# 70604  1411062.68           5.0            5.0
# 70605   101867.07           6.0            6.0
# 70606    40745.00           3.0            3.0
# 70607   475114.69           4.0            4.0
# 70608   157498.73           7.0            7.0
#
# [70609 rows x 9 columns]

# %%
df_experiment = pd.read_csv('df_final_experiment_clients.txt')
df_experiment
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
df_1 = pd.read_csv('df_final_web_data_pt_1.txt')
df_1
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 343136    2443347  465784886_73090545671  136329900_10529659391_316129
# 343137    2443347  465784886_73090545671  136329900_10529659391_316129
# 343138    2443347  465784886_73090545671  136329900_10529659391_316129
# 343139    2443347  465784886_73090545671  136329900_10529659391_316129
# 343140    2443347  465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# 1            step_2  2017-04-17 15:26:51
# 2            step_3  2017-04-17 15:19:22
# 3            step_2  2017-04-17 15:19:13
# 4            step_3  2017-04-17 15:18:04
# ...             ...                  ...
# 343136      confirm  2017-03-31 15:15:46
# 343137       step_3  2017-03-31 15:14:53
# 343138       step_2  2017-03-31 15:12:08
# 343139       step_1  2017-03-31 15:11:37
# 343140        start  2017-03-31 15:10:47
#
# [343141 rows x 5 columns]

# %%
df_2 = pd.read_csv('df_final_web_data_pt_2.txt')
df_2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# 1           confirm  2017-06-01 11:59:27
# 2            step_3  2017-06-01 11:58:48
# 3            step_2  2017-06-01 11:58:08
# 4            step_1  2017-06-01 11:57:58
# ...             ...                  ...
# 412259        start  2017-05-24 18:46:10
# 412260        start  2017-05-24 18:45:29
# 412261       step_1  2017-05-24 18:44:51
# 412262        start  2017-05-24 18:44:34
# 412263        start  2017-06-03 12:17:09
#
# [412264 rows x 5 columns]

# %%
df_web = pd.concat([df_1, df_2], axis=0)
df_web
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# 1            step_2  2017-04-17 15:26:51
# 2            step_3  2017-04-17 15:19:22
# 3            step_2  2017-04-17 15:19:13
# 4            step_3  2017-04-17 15:18:04
# ...             ...                  ...
# 412259        start  2017-05-24 18:46:10
# 412260        start  2017-05-24 18:45:29
# 412261       step_1  2017-05-24 18:44:51
# 412262        start  2017-05-24 18:44:34
# 412263        start  2017-06-03 12:17:09
#
# [755405 rows x 5 columns]

# %%
df = pd.merge(df_demo, df_experiment, on='client_id', how='left')
df
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth Variation
# 0        45105.30           6.0            9.0      Test
# 1       110860.30           6.0            9.0   Control
# 2        52467.79           6.0            9.0      Test
# 3        67454.65           3.0            6.0      Test
# 4       103671.75           0.0            3.0   Control
# ...           ...           ...            ...       ...
# 70604  1411062.68           5.0            5.0       NaN
# 70605   101867.07           6.0            6.0       NaN
# 70606    40745.00           3.0            3.0       NaN
# 70607   475114.69           4.0            4.0       NaN
# 70608   157498.73           7.0            7.0       NaN
#
# [70609 rows x 10 columns]

# %%
df = pd.merge(df_web, df, on='client_id', how='left')

# %%
df.head(50)
# Out:
#     client_id             visitor_id                      visit_id  \
# 0     9988021   580560515_7732621733  781255054_21935453173_531117
# 1     9988021   580560515_7732621733  781255054_21935453173_531117
# 2     9988021   580560515_7732621733  781255054_21935453173_531117
# 3     9988021   580560515_7732621733  781255054_21935453173_531117
# 4     9988021   580560515_7732621733  781255054_21935453173_531117
# 5     9988021   580560515_7732621733  781255054_21935453173_531117
# 6     9988021   580560515_7732621733  781255054_21935453173_531117
# 7     9988021   580560515_7732621733  781255054_21935453173_531117
# 8     8320017   39393514_33118319366  960651974_70596002104_312201
# 9     8320017   39393514_33118319366  960651974_70596002104_312201
# 10    8320017   39393514_33118319366  960651974_70596002104_312201
# 11    8320017   39393514_33118319366  960651974_70596002104_312201
# 12    8320017   39393514_33118319366  960651974_70596002104_312201
# 13    4033851  762728880_76361333336  949661017_22392791362_127391
# 14    4033851  762728880_76361333336  949661017_22392791362_127391
# 15    4033851  762728880_76361333336  949661017_22392791362_127391
# 16    4033851  762728880_76361333336  949661017_22392791362_127391
# 17    4033851  762728880_76361333336  949661017_22392791362_127391
# 18    4033851  762728880_76361333336  949661017_22392791362_127391
# 19    4033851  762728880_76361333336  949661017_22392791362_127391
# 20    4033851  762728880_76361333336  949661017_22392791362_127391
# 21    4033851  762728880_76361333336  949661017_22392791362_127391
# 22    4033851  762728880_76361333336  949661017_22392791362_127391
# 23    4033851  762728880_76361333336  949661017_22392791362_127391
# 24    1982004  618934751_10082078917   132494692_73738638511_70823
# 25    1982004  618934751_10082078917   132494692_73738638511_70823
# 26    1982004  618934751_10082078917   132494692_73738638511_70823
# 27    1982004  618934751_10082078917   132494692_73738638511_70823
# 28    1982004  618934751_10082078917   132494692_73738638511_70823
# 29    9294070  489274391_63794562906  116640698_27328181095_188045
# 30    9294070  489274391_63794562906  116640698_27328181095_188045
# 31    9466803    97277031_5793723360   812185460_4263902139_352107
# 32    9466803    97277031_5793723360   812185460_4263902139_352107
# 33    9466803    97277031_5793723360   812185460_4263902139_352107
# 34    9466803    97277031_5793723360   812185460_4263902139_352107
# 35    9466803    97277031_5793723360   812185460_4263902139_352107
# 36    9466803    97277031_5793723360   812185460_4263902139_352107
# 37    3170143  837774974_91015515080  758001412_25057963943_219559
# 38    3170143  837774974_91015515080  758001412_25057963943_219559
# 39    3170143  837774974_91015515080  758001412_25057963943_219559
# 40    3170143  837774974_91015515080  758001412_25057963943_219559
# 41    3170143  837774974_91015515080  758001412_25057963943_219559
# 42    6651403  387438258_49845138949  754106292_61370647593_160929
# 43    6651403  387438258_49845138949  754106292_61370647593_160929
# 44    6651403  387438258_49845138949  754106292_61370647593_160929
# 45    6651403  387438258_49845138949  754106292_61370647593_160929
# 46    6651403  387438258_49845138949  754106292_61370647593_160929
# 47    6651403  387438258_49845138949  754106292_61370647593_160929
# 48    6651403  387438258_49845138949  754106292_61370647593_160929
# 49    5887227  448202785_26003228044  458489157_53226123692_778999
#
#    process_step            date_time  clnt_tenure_yr  clnt_tenure_mnth  \
# 0        step_3  2017-04-17 15:27:07             5.0              64.0
# 1        step_2  2017-04-17 15:26:51             5.0              64.0
# 2        step_3  2017-04-17 15:19:22             5.0              64.0
# 3        step_2  2017-04-17 15:19:13             5.0              64.0
# 4        step_3  2017-04-17 15:18:04             5.0              64.0
# 5        step_2  2017-04-17 15:17:15             5.0              64.0
# 6        step_1  2017-04-17 15:17:01             5.0              64.0
# 7         start  2017-04-17 15:16:22             5.0              64.0
# 8       confirm  2017-04-05 13:10:05            22.0             274.0
# 9        step_3  2017-04-05 13:09:43            22.0             274.0
# 10       step_2  2017-04-05 13:08:40            22.0             274.0
# 11       step_1  2017-04-05 13:08:24            22.0             274.0
# 12        start  2017-04-05 13:08:06            22.0             274.0
# 13      confirm  2017-04-05 12:29:03            12.0             149.0
# 14      confirm  2017-04-05 12:29:01            12.0             149.0
# 15      confirm  2017-04-05 12:28:52            12.0             149.0
# 16       step_3  2017-04-05 12:26:08            12.0             149.0
# 17       step_2  2017-04-05 12:24:43            12.0             149.0
# 18       step_1  2017-04-05 12:24:12            12.0             149.0
# 19        start  2017-04-05 12:24:04            12.0             149.0
# 20       step_2  2017-04-05 12:10:26            12.0             149.0
# 21       step_3  2017-04-05 12:10:26            12.0             149.0
# 22       step_2  2017-04-05 12:10:25            12.0             149.0
# 23       step_3  2017-04-05 12:10:25            12.0             149.0
# 24      confirm  2017-04-17 12:02:42             6.0              80.0
# 25       step_3  2017-04-17 12:01:09             6.0              80.0
# 26       step_2  2017-04-17 12:00:01             6.0              80.0
# 27       step_1  2017-04-17 11:59:46             6.0              80.0
# 28        start  2017-04-17 11:59:42             6.0              80.0
# 29        start  2017-04-17 11:16:28             5.0              70.0
# 30        start  2017-04-17 11:16:13             5.0              70.0
# 31        start  2017-04-16 13:24:45            11.0             137.0
# 32       step_2  2017-04-16 13:24:16            11.0             137.0
# 33       step_1  2017-04-16 13:24:07            11.0             137.0
# 34        start  2017-04-16 13:24:05            11.0             137.0
# 35       step_1  2017-04-16 13:21:58            11.0             137.0
# 36        start  2017-04-16 13:21:51            11.0             137.0
# 37      confirm  2017-04-04 18:41:44            21.0             254.0
# 38       step_3  2017-04-04 18:41:03            21.0             254.0
# 39       step_2  2017-04-04 18:38:22            21.0             254.0
# 40       step_1  2017-04-04 18:38:14            21.0             254.0
# 41        start  2017-04-04 18:38:02            21.0             254.0
# 42      confirm  2017-04-04 17:38:39            13.0             162.0
# 43       step_3  2017-04-04 17:34:03            13.0             162.0
# 44       step_2  2017-04-04 17:33:55            13.0             162.0
# 45       step_3  2017-04-04 17:31:32            13.0             162.0
# 46       step_2  2017-04-04 17:28:44            13.0             162.0
# 47       step_1  2017-04-04 17:28:35            13.0             162.0
# 48        start  2017-04-04 17:28:18            13.0             162.0
# 49      confirm  2017-04-05 14:52:34             6.0              79.0
#
#     clnt_age gendr  num_accts        bal  calls_6_mnth  logons_6_mnth  \
# 0       79.0     U        2.0  189023.86           1.0            4.0
# 1       79.0     U        2.0  189023.86           1.0            4.0
# 2       79.0     U        2.0  189023.86           1.0            4.0
# 3       79.0     U        2.0  189023.86           1.0            4.0
# 4       79.0     U        2.0  189023.86           1.0            4.0
# 5       79.0     U        2.0  189023.86           1.0            4.0
# 6       79.0     U        2.0  189023.86           1.0            4.0
# 7       79.0     U        2.0  189023.86           1.0            4.0
# 8       34.5     M        2.0   36001.90           5.0            8.0
# 9       34.5     M        2.0   36001.90           5.0            8.0
# 10      34.5     M        2.0   36001.90           5.0            8.0
# 11      34.5     M        2.0   36001.90           5.0            8.0
# 12      34.5     M        2.0   36001.90           5.0            8.0
# 13      63.5     M        2.0  142642.26           5.0            8.0
# 14      63.5     M        2.0  142642.26           5.0            8.0
# 15      63.5     M        2.0  142642.26           5.0            8.0
# 16      63.5     M        2.0  142642.26           5.0            8.0
# 17      63.5     M        2.0  142642.26           5.0            8.0
# 18      63.5     M        2.0  142642.26           5.0            8.0
# 19      63.5     M        2.0  142642.26           5.0            8.0
# 20      63.5     M        2.0  142642.26           5.0            8.0
# 21      63.5     M        2.0  142642.26           5.0            8.0
# 22      63.5     M        2.0  142642.26           5.0            8.0
# 23      63.5     M        2.0  142642.26           5.0            8.0
# 24      44.5     U        2.0   30231.76           1.0            4.0
# 25      44.5     U        2.0   30231.76           1.0            4.0
# 26      44.5     U        2.0   30231.76           1.0            4.0
# 27      44.5     U        2.0   30231.76           1.0            4.0
# 28      44.5     U        2.0   30231.76           1.0            4.0
# 29      29.0     U        2.0   34254.54           0.0            3.0
# 30      29.0     U        2.0   34254.54           0.0            3.0
# 31      27.0     F        2.0   46131.19           1.0            4.0
# 32      27.0     F        2.0   46131.19           1.0            4.0
# 33      27.0     F        2.0   46131.19           1.0            4.0
# 34      27.0     F        2.0   46131.19           1.0            4.0
# 35      27.0     F        2.0   46131.19           1.0            4.0
# 36      27.0     F        2.0   46131.19           1.0            4.0
# 37      53.5     F        2.0  192109.59           6.0            9.0
# 38      53.5     F        2.0  192109.59           6.0            9.0
# 39      53.5     F        2.0  192109.59           6.0            9.0
# 40      53.5     F        2.0  192109.59           6.0            9.0
# 41      53.5     F        2.0  192109.59           6.0            9.0
# 42      56.5     M        2.0  324712.88           4.0            7.0
# 43      56.5     M        2.0  324712.88           4.0            7.0
# 44      56.5     M        2.0  324712.88           4.0            7.0
# 45      56.5     M        2.0  324712.88           4.0            7.0
# 46      56.5     M        2.0  324712.88           4.0            7.0
# 47      56.5     M        2.0  324712.88           4.0            7.0
# 48      56.5     M        2.0  324712.88           4.0            7.0
# 49      32.5     U        2.0   60274.39           1.0            4.0
#
#    Variation
# 0       Test
# 1       Test
# 2       Test
# 3       Test
# 4       Test
# 5       Test
# 6       Test
# 7       Test
# 8       Test
# 9       Test
# 10      Test
# 11      Test
# 12      Test
# 13   Control
# 14   Control
# 15   Control
# 16   Control
# 17   Control
# 18   Control
# 19   Control
# 20   Control
# 21   Control
# 22   Control
# 23   Control
# 24      Test
# 25      Test
# 26      Test
# 27      Test
# 28      Test
# 29   Control
# 30   Control
# 31      Test
# 32      Test
# 33      Test
# 34      Test
# 35      Test
# 36      Test
# 37      Test
# 38      Test
# 39      Test
# 40      Test
# 41      Test
# 42   Control
# 43   Control
# 44   Control
# 45   Control
# 46   Control
# 47   Control
# 48   Control
# 49      Test

# %%
df.rename(columns={'Variation': 'variation'}, inplace=True)

# %%
df.isnull().sum()
# Out:
# client_id                0
# visitor_id               0
# visit_id                 0
# process_step             0
# date_time                0
# clnt_tenure_yr      305689
# clnt_tenure_mnth    305689
# clnt_age            305701
# gendr               305689
# num_accts           305689
# bal                 305689
# calls_6_mnth        305689
# logons_6_mnth       305689
# variation           434096
# dtype: int64

# %%
df.dropna(subset=['clnt_age', 'clnt_tenure_yr', 'clnt_tenure_mnth', 'gendr', 'num_accts', 'bal', 'calls_6_mnth', 'logons_6_mnth', 'variation'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 321195 entries, 0 to 637535
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   client_id         321195 non-null  int64
#  1   visitor_id        321195 non-null  object
#  2   visit_id          321195 non-null  object
#  3   process_step      321195 non-null  object
#  4   date_time         321195 non-null  object
#  5   clnt_tenure_yr    321195 non-null  float64
#  6   clnt_tenure_mnth  321195 non-null  float64
#  7   clnt_age          321195 non-null  float64
#  8   gendr             321195 non-null  object
#  9   num_accts         321195 non-null  float64
#  10  bal               321195 non-null  float64
#  11  calls_6_mnth      321195 non-null  float64
#  12  logons_6_mnth     321195 non-null  float64
#  13  variation         321195 non-null  object
# dtypes: float64(7), int64(1), object(6)
# memory usage: 36.8+ MB

# %%
df.describe()
# Out:
#           client_id  clnt_tenure_yr  clnt_tenure_mnth       clnt_age  \
# count  3.211950e+05   321195.000000     321195.000000  321195.000000
# mean   5.009766e+06       12.176528        152.134818      48.553511
# std    2.872653e+06        6.963181         83.210462      15.645588
# min    5.550000e+02        2.000000         33.000000      17.000000
# 25%    2.514553e+06        6.000000         82.000000      34.500000
# 50%    5.051667e+06       11.000000        138.000000      50.000000
# 75%    7.468390e+06       16.000000        193.000000      61.000000
# max    9.999832e+06       55.000000        669.000000      96.000000
#
#            num_accts           bal   calls_6_mnth  logons_6_mnth
# count  321195.000000  3.211950e+05  321195.000000  321195.000000
# mean        2.262962  1.622142e+05       3.236834       6.275082
# std         0.541536  3.494776e+05       2.193690       2.179757
# min         1.000000  2.378944e+04       0.000000       3.000000
# 25%         2.000000  4.105887e+04       1.000000       4.000000
# 50%         2.000000  6.924195e+04       3.000000       6.000000
# 75%         2.000000  1.514930e+05       6.000000       9.000000
# max         7.000000  1.632004e+07       6.000000       9.000000

# %%
df['client_id'].nunique()
# Out:
# 50487

# %%
potential_categorical_from_numerical = df.select_dtypes("number").loc[:, df.select_dtypes("number").nunique() < 20]
potential_categorical_from_numerical
# Out:
#         num_accts  calls_6_mnth  logons_6_mnth
# 0             2.0           1.0            4.0
# 1             2.0           1.0            4.0
# 2             2.0           1.0            4.0
# 3             2.0           1.0            4.0
# 4             2.0           1.0            4.0
# ...           ...           ...            ...
# 637487        2.0           3.0            6.0
# 637532        3.0           6.0            9.0
# 637533        3.0           6.0            9.0
# 637534        3.0           6.0            9.0
# 637535        3.0           6.0            9.0
#
# [321195 rows x 3 columns]

# %%
df_categorical = pd.concat([df.select_dtypes("object"), potential_categorical_from_numerical], axis=1)

df_numerical = df.select_dtypes("number").drop(columns=potential_categorical_from_numerical.columns)

# %%
avg_age_tenure_by_gender = df.groupby('gendr')[['clnt_age', 'clnt_tenure_yr']].mean()
avg_age_tenure_by_gender
# Out:
#         clnt_age  clnt_tenure_yr
# gendr
# F      51.658841       14.911535
# M      50.765380       15.033653
# U      43.386039        6.722788
# X      34.750000       10.250000

# %%
df['engagement'] = df['logons_6_mnth'] + df['calls_6_mnth']

avg_engagement_by_tenure = df.groupby('clnt_tenure_yr')['engagement'].mean()
print(avg_engagement_by_tenure)
# Out:
# clnt_tenure_yr
# 2.0     10.221951
# 3.0      9.560072
# 4.0      9.175424
# 5.0      9.485114
# 6.0      9.563260
# 7.0      9.622417
# 8.0      9.329626
# 9.0      9.235593
# 10.0     9.191198
# 11.0     9.038714
# 12.0     9.001893
# 13.0     9.171962
# 14.0     8.835204
# 15.0     9.124514
# 16.0     9.653475
# 17.0    10.028774
# 18.0    10.200699
# 19.0    10.191171
# 20.0     9.905517
# 21.0    10.536933
# 22.0    10.010146
# 23.0    10.085557
# 24.0    10.441441
# 25.0    10.456531
# 26.0    10.115530
# 27.0    10.088280
# 28.0     9.995289
# 29.0    10.577195
# 30.0    10.858307
# 31.0    11.314103
# 32.0    11.307955
# 33.0     9.983271
# 34.0    11.193955
# 35.0    10.646950
# 36.0    10.901961
# 37.0     9.196721
# 38.0    10.565891
# 39.0    10.096774
# 40.0    11.650000
# 41.0    15.000000
# 42.0     7.526316
# 43.0    11.695652
# 44.0     7.705882
# 45.0     9.000000
# 46.0     9.606061
# 47.0     9.130435
# 48.0     9.083333
# 49.0    11.500000
# 50.0    12.571429
# 51.0     5.200000
# 52.0    15.000000
# 54.0     7.000000
# 55.0     7.533333
# Name: engagement, dtype: float64

# %%
df['date_time'] = pd.to_datetime(df['date_time'])

# %%
visits_per_day = df.resample('D', on='date_time').size()
visits_per_day.plot(figsize=(10, 6))
plt.title('Number of Web Visits Per Day')
plt.xlabel('Date')
plt.ylabel('Number of Visits')
plt.show()

# %%
# Analyse client age distribution
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='clnt_age', kde=True)
plt.title('Client Age Distribution')
plt.show()

print(f"Average Client Age: {df['clnt_age'].mean()}")
# Out:
# /Users/kwameantwiadjei/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Average Client Age: 48.553511106959945

# %%
# Analyse client tenure distribution
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='clnt_tenure_yr', kde=True)
plt.title('Client Tenure Distribution')
plt.show()

print(f"Average Client Tenure: {df['clnt_tenure_yr'].mean()}")
# Out:
# /Users/kwameantwiadjei/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Average Client Tenure: 12.176528277214777

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='process_step', order=df['process_step'].value_counts().index)
plt.title('Process Step Frequencies')
plt.xticks(rotation=45)
plt.show()

# %%
client_numerical_cols = ['clnt_age', 'clnt_tenure_yr', 'num_accts', 'bal', 'calls_6_mnth', 'logons_6_mnth']
client_corr = df[client_numerical_cols].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(client_corr, annot=True, cmap="coolwarm")
plt.title('Client Data Correlation Matrix')
plt.show()

# %%
df['variation'].unique()
# Out:
# array(['Test', 'Control'], dtype=object)

# %%
df.groupby('variation')['client_id'].nunique()
# Out:
# variation
# Control    23526
# Test       26961
# Name: client_id, dtype: int64

# %%
# Step 1: Filter the DataFrame for 'confirm' step entries
users_reached_confirm = df[df['process_step'] == 'confirm']['client_id'].nunique()

# Step 2: Count total unique client_ids in the entire dataset
total_users = df['client_id'].nunique()

# Step 3: Calculate the completion rate
completion_rate = users_reached_confirm / total_users

print(f"Completion Rate: {completion_rate:.2%}")
# Out:
# Completion Rate: 67.56%

# %%
# Group by 'variation' and filter for 'confirm' step, then count unique client_ids
confirm_by_variation = df[df['process_step'] == 'confirm'].groupby('variation')['client_id'].nunique()

# Count total unique client_ids for each variation
total_users_by_variation = df.groupby('variation')['client_id'].nunique()

# Calculate the completion rate for each variation
completion_rate_by_variation = confirm_by_variation / total_users_by_variation

print("Completion Rate by Variation:")
print(completion_rate_by_variation)
# Out:
# Completion Rate by Variation:
# variation
# Control    0.655785
# Test       0.692927
# Name: client_id, dtype: float64

# %%
# Sort the DataFrame to ensure the calculation of exit times is accurate
df.sort_values(by=['client_id', 'date_time'], inplace=True)

# Infer the exit time for each step as the date_time of the next action
df['exit_time'] = df.groupby('client_id')['date_time'].shift(-1)

# Calculate the duration spent on each step in seconds
df['duration_seconds'] = (df['exit_time'] - df['date_time']).dt.total_seconds()

# Exclude the last action of each session since its duration cannot be accurately calculated
df = df.dropna(subset=['duration_seconds'])

# Group by client_id and process_step to calculate the average duration for each user and step
average_durations_per_user = df.groupby(['client_id', 'process_step'])['duration_seconds'].mean().reset_index()

# Display the result
print("Average Duration by Process Step per User (in seconds):")
print(average_durations_per_user)
# Out:
# Average Duration by Process Step per User (in seconds):
#         client_id process_step  duration_seconds
# 0             555        start          7.000000
# 1             555       step_1         32.000000
# 2             555       step_2         99.000000
# 3             555       step_3         20.000000
# 4             647        start          7.000000
# ...           ...          ...               ...
# 173237    9999729        start     390317.500000
# 173238    9999729       step_1     432906.666667
# 173239    9999729       step_2         60.000000
# 173240    9999729       step_3         21.000000
# 173241    9999832        start          8.000000
#
# [173242 rows x 3 columns]

# %%
df['duration_seconds'].mean()
# Out:
# 77224.53065295448

# %%
df['duration_seconds'].sort_values(ascending=True).head()
# Out:
# 429132    0.0
# 55567     0.0
# 77028     0.0
# 77026     0.0
# 465301    0.0
# Name: duration_seconds, dtype: float64

# %%
df.groupby('process_step')['duration_seconds'].mean().reset_index(name='average_duration_seconds')
# Out:
#   process_step  average_duration_seconds
# 0      confirm             339046.096893
# 1        start             110283.797313
# 2       step_1              49133.113849
# 3       step_2              27216.980919
# 4       step_3              45462.733505

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='process_step', y='duration_seconds', data=df)
plt.title('Boxplot of Duration per Process Step')
plt.ylabel('Duration (seconds)')
plt.xlabel('Process Step')
plt.xticks(rotation=45)
plt.show()

# %%
Q1 = df['duration_seconds'].quantile(0.25)
Q3 = df['duration_seconds'].quantile(0.75)
IQR = Q3 - Q1

# Define limits
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

# Cap the outliers
df['duration_seconds'] = df['duration_seconds'].clip(lower=lower_limit, upper=upper_limit)

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='process_step', y='duration_seconds', data=df)
plt.title('Adjusted Boxplot of Duration per Process Step')
plt.ylabel('Duration (seconds)')
plt.xlabel('Process Step')
plt.xticks(rotation=45)
plt.show()

# %%
def remove_outliers(group):
    Q1 = group['duration_seconds'].quantile(0.25)
    Q3 = group['duration_seconds'].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    group['duration_seconds'] = group['duration_seconds'].clip(lower=lower, upper=upper)
    return group

# %%
df.groupby('process_step').apply(remove_outliers)
# Out:
#                      client_id             visitor_id  \
# process_step
# confirm      592188       1336  920624746_32603333901
#              592150       1336  920624746_32603333901
#              189056       1702  470573753_93844895765
#              569070       1702  470573753_93844895765
#              48848        1836  619440135_40983729273
# ...                        ...                    ...
# step_3       136501    9998851  660529049_81285947655
#              99213     9998964  502193753_63097042630
#              39682     9999009  212849256_28644888524
#              181423    9999400  915967319_19082377501
#              471737    9999729  834634258_21862004160
#
#                                          visit_id process_step  \
# process_step
# confirm      592188  583743392_96265099036_939815      confirm
#              592150  614001770_19101025926_112779      confirm
#              189056  243444359_78696078676_118990      confirm
#              569070   825109778_55379502512_27372      confirm
#              48848   624455994_87386716654_950064      confirm
# ...                                           ...          ...
# step_3       136501  310744937_17135608286_213964       step_3
#              99213   699981922_52880598802_858635       step_3
#              39682   149965839_24823291142_245569       step_3
#              181423  288904166_90826265353_276104       step_3
#              471737  870243567_56915814033_814203       step_3
#
#                               date_time  clnt_tenure_yr  clnt_tenure_mnth  \
# process_step
# confirm      592188 2017-05-08 06:08:43            48.0             576.0
#              592150 2017-05-08 08:21:38            48.0             576.0
#              189056 2017-04-01 11:44:04            21.0             260.0
#              569070 2017-06-05 12:04:58            21.0             260.0
#              48848  2017-04-05 18:49:51            13.0             157.0
# ...                                 ...             ...               ...
# step_3       136501 2017-04-05 12:08:12             4.0              58.0
#              99213  2017-04-05 23:48:48             5.0              71.0
#              39682  2017-03-31 07:18:38            18.0             216.0
#              181423 2017-04-20 05:23:03             7.0              86.0
#              471737 2017-05-08 16:09:19            10.0             124.0
#
#                      clnt_age gendr  num_accts         bal  calls_6_mnth  \
# process_step
# confirm      592188      42.0     M        4.0   130537.18           6.0
#              592150      42.0     M        4.0   130537.18           6.0
#              189056      62.5     U        3.0  1769255.99           5.0
#              569070      62.5     U        3.0  1769255.99           5.0
#              48848       51.5     M        2.0   826232.62           4.0
# ...                       ...   ...        ...         ...           ...
# step_3       136501      23.5     U        2.0    38473.54           3.0
#              99213       45.5     U        3.0    91766.49           6.0
#              39682       68.5     M        3.0  2055381.29           6.0
#              181423      28.5     U        2.0    51787.04           0.0
#              471737      31.0     F        3.0   107059.74           6.0
#
#                      logons_6_mnth variation  engagement           exit_time  \
# process_step
# confirm      592188            9.0      Test        15.0 2017-05-08 08:21:38
#              592150            9.0      Test        15.0 2017-05-08 08:23:00
#              189056            8.0      Test        13.0 2017-06-05 12:04:58
#              569070            8.0      Test        13.0 2017-06-11 09:47:25
#              48848             7.0      Test        11.0 2017-04-05 18:53:03
# ...                            ...       ...         ...                 ...
# step_3       136501            6.0      Test         9.0 2017-04-05 12:08:43
#              99213             9.0      Test        15.0 2017-04-05 23:50:02
#              39682             9.0      Test        15.0 2017-03-31 07:20:36
#              181423            3.0      Test         3.0 2017-04-20 05:23:27
#              471737            9.0      Test        15.0 2017-05-08 16:09:40
#
#                      duration_seconds
# process_step
# confirm      592188             231.5
#              592150              82.0
#              189056             231.5
#              569070             231.5
#              48848              192.0
# ...                               ...
# step_3       136501              31.0
#              99213               74.0
#              39682              118.0
#              181423              24.0
#              471737              21.0
#
# [270708 rows x 17 columns]

# %%
# Calculate the mean duration for each process step, segmented by variation group
mean_duration_by_step_and_variation = df.groupby(['process_step', 'variation'])['duration_seconds'].mean().reset_index(name='mean_duration_seconds')

# Display the result
print("Mean Duration by Process Step and Variation Group (in seconds):")
print(mean_duration_by_step_and_variation)
# Out:
# Mean Duration by Process Step and Variation Group (in seconds):
#   process_step variation  mean_duration_seconds
# 0      confirm   Control             144.426642
# 1      confirm      Test             165.045815
# 2        start   Control              59.563358
# 3        start      Test              54.488531
# 4       step_1   Control              47.612839
# 5       step_1      Test              54.599164
# 6       step_2   Control              83.756791
# 7       step_2      Test              79.348384
# 8       step_3   Control             101.884022
# 9       step_3      Test              91.491777

# %%
df.sort_values(by=['client_id', 'date_time'], inplace=True)

# %%
# This mapping should reflect the actual order of your process steps
step_order = {
    'start': 1,
    'step_1': 2,
    'step_2': 3,
    'step_3': 4,
    'confirm': 5
}

# Map the process steps to their numerical order
df['step_order'] = df['process_step'].map(step_order)

# %%
# Sort the DataFrame by user and time to ensure correct sequence
df.sort_values(by=['client_id', 'date_time'], inplace=True)

# Identify backward movements
df['next_step_order'] = df.groupby('client_id')['step_order'].shift(-1)
df['is_backward'] = df['step_order'] > df['next_step_order']

# %%
# Calculate error instances per step
errors_per_step = df.groupby('process_step')['is_backward'].sum()

# Calculate total instances per step for normalization
total_instances_per_step = df.groupby('process_step')['is_backward'].count()

# Error rate per step
error_rate_per_step = errors_per_step / total_instances_per_step
print("Error Rate per Process Step:")
print(error_rate_per_step)

# For error rates per variation, you'd group by variation instead
errors_per_variation = df.groupby('variation')['is_backward'].sum()
total_instances_per_variation = df.groupby('variation')['is_backward'].count()
error_rate_per_variation = errors_per_variation / total_instances_per_variation
print("\nError Rate per Variation Group:")
print(error_rate_per_variation)
# Out:
# Error Rate per Process Step:
# process_step
# confirm    0.176280
# start      0.000000
# step_1     0.146855
# step_2     0.129104
# step_3     0.205804
# Name: is_backward, dtype: float64
#
# Error Rate per Variation Group:
# variation
# Control    0.097396
# Test       0.109524
# Name: is_backward, dtype: float64

# %%
# Example code to create a 'completed' column
df['completed'] = (df['process_step'] == 'confirm').astype(int)

# Calculate completion rates
completion_rate_test = df[df['variation'] == 'Test']['completed'].mean()
completion_rate_control = df[df['variation'] == 'Control']['completed'].mean()

# %%
completion_rate_test
# Out:
# 0.05021680612096058

# %%
completion_rate_control
# Out:
# 0.03212325453362473

# %%
from statsmodels.stats.proportion import proportions_ztest

# Counts of successes (users who completed the process) in each group
successes = np.array([
    df[df['variation'] == 'Test']['completed'].sum(),
    df[df['variation'] == 'Control']['completed'].sum()
])

# Total number of users in each group
users = np.array([
    df[df['variation'] == 'Test']['completed'].count(),
    df[df['variation'] == 'Control']['completed'].count()
])

# Perform the Two-Proportion Z-test
stat, pval = proportions_ztest(count=successes, nobs=users)

# Evaluate the results
print(f"Z-statistic: {stat:.2f}")
print(f"p-value: {pval:.4f}")

alpha = 0.05
if pval < alpha:
    print("Reject the null hypothesis: There is a significant difference in completion rates.")
else:
    print("Fail to reject the null hypothesis: No significant difference in completion rates.")
# Out:
# Z-statistic: 23.26
# p-value: 0.0000
# Reject the null hypothesis: There is a significant difference in completion rates.

# %%
# Calculate completion rates
completion_rate_test = df[df['variation'] == 'Test']['completed'].mean()
completion_rate_control = df[df['variation'] == 'Control']['completed'].mean()

# Calculate the observed increase in completion rates
observed_increase = completion_rate_test - completion_rate_control

# 5% threshold
threshold = 0.05  

# Check if the observed increase meets or exceeds the threshold
if observed_increase >= threshold:
    print(f"The observed increase in completion rate of {observed_increase:.2%} meets or exceeds the 5% threshold. The new design may be considered cost-effective.")
else:
    print(f"The observed increase in completion rate of {observed_increase:.2%} does not meet the 5% threshold. The new design may not justify the costs from a cost-effectiveness perspective.")
# Out:
# The observed increase in completion rate of 1.81% does not meet the 5% threshold. The new design may not justify the costs from a cost-effectiveness perspective.

# %%
# Extract ages for Test and Control groups
ages_test = df[df['variation'] == 'Test']['clnt_age']
ages_control = df[df['variation'] == 'Control']['clnt_age']

# Perform the independent T-test
t_stat, p_val = stats.ttest_ind(ages_test, ages_control, equal_var=True)

print(f"T-statistic: {t_stat:.2f}")
print(f"p-value: {p_val:.4f}")

# Decision based on p-value
if p_val < 0.05:
    print("Reject the null hypothesis: There is a significant difference in the average age of clients.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in the average age of clients.")
# Out:
# T-statistic: 9.32
# p-value: 0.0000
# Reject the null hypothesis: There is a significant difference in the average age of clients.

# %%
df
# Out:
#         client_id             visitor_id                      visit_id  \
# 72018         555  402506806_56087378777  637149525_38041617439_716659
# 72017         555  402506806_56087378777  637149525_38041617439_716659
# 72016         555  402506806_56087378777  637149525_38041617439_716659
# 72015         555  402506806_56087378777  637149525_38041617439_716659
# 138182        647   66758770_53988066587   40369564_40101682850_311847
# ...           ...                    ...                           ...
# 471740    9999729  834634258_21862004160  870243567_56915814033_814203
# 471739    9999729  834634258_21862004160  870243567_56915814033_814203
# 471738    9999729  834634258_21862004160  870243567_56915814033_814203
# 471737    9999729  834634258_21862004160  870243567_56915814033_814203
# 356799    9999832  145538019_54444341400  472154369_16714624241_585315
#
#        process_step           date_time  clnt_tenure_yr  clnt_tenure_mnth  \
# 72018         start 2017-04-15 12:57:56             3.0              46.0
# 72017        step_1 2017-04-15 12:58:03             3.0              46.0
# 72016        step_2 2017-04-15 12:58:35             3.0              46.0
# 72015        step_3 2017-04-15 13:00:14             3.0              46.0
# 138182        start 2017-04-12 15:41:28            12.0             151.0
# ...             ...                 ...             ...               ...
# 471740        start 2017-05-08 16:08:25            10.0             124.0
# 471739       step_1 2017-05-08 16:08:30            10.0             124.0
# 471738       step_2 2017-05-08 16:08:40            10.0             124.0
# 471737       step_3 2017-05-08 16:09:19            10.0             124.0
# 356799        start 2017-05-16 16:46:03            23.0             281.0
#
#         clnt_age gendr  num_accts  ...  calls_6_mnth  logons_6_mnth  \
# 72018       29.5     U        2.0  ...           2.0            6.0
# 72017       29.5     U        2.0  ...           2.0            6.0
# 72016       29.5     U        2.0  ...           2.0            6.0
# 72015       29.5     U        2.0  ...           2.0            6.0
# 138182      57.5     M        2.0  ...           0.0            4.0
# ...          ...   ...        ...  ...           ...            ...
# 471740      31.0     F        3.0  ...           6.0            9.0
# 471739      31.0     F        3.0  ...           6.0            9.0
# 471738      31.0     F        3.0  ...           6.0            9.0
# 471737      31.0     F        3.0  ...           6.0            9.0
# 356799      49.0     F        2.0  ...           1.0            4.0
#
#         variation engagement           exit_time duration_seconds  step_order  \
# 72018        Test        8.0 2017-04-15 12:58:03              7.0           1
# 72017        Test        8.0 2017-04-15 12:58:35             32.0           2
# 72016        Test        8.0 2017-04-15 13:00:14             99.0           3
# 72015        Test        8.0 2017-04-15 13:00:34             20.0           4
# 138182       Test        4.0 2017-04-12 15:41:35              7.0           1
# ...           ...        ...                 ...              ...         ...
# 471740       Test       15.0 2017-05-08 16:08:30              5.0           1
# 471739       Test       15.0 2017-05-08 16:08:40             10.0           2
# 471738       Test       15.0 2017-05-08 16:09:19             39.0           3
# 471737       Test       15.0 2017-05-08 16:09:40             21.0           4
# 356799       Test        5.0 2017-05-16 16:46:11              8.0           1
#
#         next_step_order  is_backward  completed
# 72018               2.0        False          0
# 72017               3.0        False          0
# 72016               4.0        False          0
# 72015               NaN        False          0
# 138182              2.0        False          0
# ...                 ...          ...        ...
# 471740              2.0        False          0
# 471739              3.0        False          0
# 471738              4.0        False          0
# 471737              NaN        False          0
# 356799              NaN        False          0
#
# [270708 rows x 21 columns]

# %%
df.to_csv('Vanguard_clean.csv', index=False)

# %%
df['clnt_age'].max()
# Out:
# 96.0
